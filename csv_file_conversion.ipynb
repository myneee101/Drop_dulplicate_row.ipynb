# %%
f = open("/home/lamda/Desktop/paper/train_dronet.csv", "w")
f.write('file,label')
for x in 
f.close()

# %%
fout = open("/home/lamda/Desktop/Avd/trojai-master/Dronet/dronet_mynuddin_discrete/validation/HMB_1_501/validation.csv", "w")
fout.write('file,label\n')

f = open("/home/lamda/Desktop/Avd/trojai-master/Dronet/dronet_mynuddin_discrete/validation/HMB_1_501/list.txt", "r")
label = open("/home/lamda/Desktop/Avd/trojai-master/Dronet/dronet_mynuddin_discrete/validation/HMB_1_501/sync_steering.txt", "r")
for x in f:
    xx = label.readline()    
    yy = 'validation/HMB_1_501/'+x[:-1]+','+xx
    print(yy)
    fout.write(yy)
fout.close()
f.close()
label.close()
# Out:
# validation/HMB_1_501/1479424410915015791.png,4
#
# validation/HMB_1_501/1479424410965007530.png,4
#
# validation/HMB_1_501/1479424411015241524.png,4
#
# validation/HMB_1_501/1479424411065025199.png,4
#
# validation/HMB_1_501/1479424411115144499.png,4
#
# validation/HMB_1_501/1479424411165043992.png,4
#
# validation/HMB_1_501/1479424411215234949.png,4
#
# validation/HMB_1_501/1479424411267357054.png,4
#
# validation/HMB_1_501/1479424411315475889.png,4
#
# validation/HMB_1_501/1479424411365142381.png,4
#
# validation/HMB_1_501/1479424411415127072.png,4
#
# validation/HMB_1_501/1479424411465261919.png,4
#
# validation/HMB_1_501/1479424411515182860.png,4
#
# validation/HMB_1_501/1479424411565034743.png,4
#
# validation/HMB_1_501/1479424411615096598.png,4
#
# validation/HMB_1_501/1479424411665096863.png,4
#
# validation/HMB_1_501/1479424411715153437.png,4
#
# validation/HMB_1_501/1479424411765185105.png,4
#
# validation/HMB_1_501/1479424411816399150.png,4
#
# ...

# %%
fout = open("/home/lamda/Desktop/paper/validation/validation_GOPR0227.csv", "w")
fout.write('file,label\n')

f = open("/home/lamda/Desktop/paper/validation/validation_list.txt", "r")
label = open("/home/lamda/Desktop/paper/validation/labels.txt", "r")
for x in f:
    xx = label.readline()    
    yy = 'validation/'+x[:-1]+','+xx
    print(yy)
    fout.write(yy)
fout.close()
f.close()
label.close()

# %%
fout = open("/home/lamda/Desktop/paper/training/train_DSCN2680.csv", "w")
fout.write('file,label\n')

f = open("/home/lamda/Desktop/paper/training/train_list.txt", "r")
label = open("/home/lamda/Desktop/paper/training/labels.txt", "r")
for x in f:
    xx = label.readline()
    yy = 'train/'+x[:-1]+','+xx
    print(yy)    
    fout.write(yy)
fout.close()
f.close()
label.close()
# Out:
# train/frame_00001.jpg,0
#
# train/frame_00002.jpg,0
#
# train/frame_00003.jpg,0
#
# train/frame_00004.jpg,0
#
# train/frame_00005.jpg,0
#
# train/frame_00006.jpg,0
#
# train/frame_00007.jpg,0
#
# train/frame_00008.jpg,0
#
# train/frame_00009.jpg,0
#
# train/frame_00010.jpg,0
#
# train/frame_00011.jpg,0
#
# train/frame_00012.jpg,0
#
# train/frame_00013.jpg,0
#
# train/frame_00014.jpg,0
#
# train/frame_00015.jpg,0
#
# train/frame_00016.jpg,0
#
# train/frame_00017.jpg,0
#
# train/frame_00018.jpg,0
#
# train/frame_00019.jpg,0
#
# train/frame_00020.jpg,0
#
# train/frame_00021.jpg,0
#
# train/frame_00022.jpg,0
#
# train/frame_00023.jpg,0
#
# train/frame_00024.jpg,0
#
# train/frame_00025.jpg,0
#
# train/frame_00026.jpg,0
#
# train/frame_00027.jpg,0
#
# train/frame_00028.jpg,0
#
# train/frame_00029.jpg,0
#
# train/frame_00030.jpg,0
#
# train/frame_00031.jpg,0
#
# train/frame_00032.jpg,0
#
# train/frame_00033.jpg,0
#
# train/frame_00034.jpg,0
#
# train/frame_00035.jpg,0
#
# ...

# %% [markdown]
# ### Collision Data

# %%
fout = open("/home/lamda/Desktop/paper/training/train_DSCN2578.csv", "w")
fout.write('file,label\n')

f = open("/home/lamda/Desktop/paper/training/train_list.txt", "r")
label = open("/home/lamda/Desktop/paper/training/labels.txt", "r")
for x in f:
    xx = label.readline()
    yy = 'train/'+x[:-1]+','+xx
    print(yy)    
    fout.write(yy)
fout.close()
f.close()
label.close()

# %%
fout = open("/home/lamda/Desktop/paper/training/train_GOPR0387.csv", "w")
fout.write('file,label\n')

f = open("/home/lamda/Desktop/paper/training/train_list.txt", "r")
label = open("/home/lamda/Desktop/paper/training/labels.txt", "r")
for x in f:
    xx = label.readline()    
    yy = 'train/'+x[:-1]+','+xx
    print(yy)
    fout.write(yy)
fout.close()
f.close()
label.close()
# Out:
# train/frame_00001.jpg,0
#
# train/frame_00002.jpg,0
#
# train/frame_00003.jpg,0
#
# train/frame_00004.jpg,0
#
# train/frame_00005.jpg,0
#
# train/frame_00006.jpg,0
#
# train/frame_00007.jpg,0
#
# train/frame_00008.jpg,0
#
# train/frame_00009.jpg,0
#
# train/frame_00010.jpg,0
#
# train/frame_00011.jpg,0
#
# train/frame_00012.jpg,0
#
# train/frame_00013.jpg,0
#
# train/frame_00014.jpg,0
#
# train/frame_00015.jpg,0
#
# train/frame_00016.jpg,0
#
# train/frame_00017.jpg,0
#
# train/frame_00018.jpg,0
#
# train/frame_00019.jpg,0
#
# train/frame_00020.jpg,0
#
# train/frame_00021.jpg,0
#
# train/frame_00022.jpg,0
#
# train/frame_00023.jpg,0
#
# train/frame_00024.jpg,0
#
# train/frame_00025.jpg,0
#
# train/frame_00026.jpg,0
#
# train/frame_00027.jpg,0
#
# train/frame_00028.jpg,0
#
# train/frame_00029.jpg,0
#
# train/frame_00030.jpg,0
#
# train/frame_00031.jpg,0
#
# train/frame_00032.jpg,0
#
# train/frame_00033.jpg,0
#
# train/frame_00034.jpg,0
#
# train/frame_00035.jpg,0
#
# ...

# %%
# import the required libraries
import torch
import torchvision.transforms.functional as T
from PIL import Image
import matplotlib.pyplot as plt
from torchvision.utils import save_image

f = open("/home/lamda/Desktop/Avd/trojai-master/scripts/modelgen/dscndata1/dronet/models/dronet_clean/train/right.txt", "r")
for x in f:
    yy = '/home/lamda/Desktop/Avd/trojai-master/scripts/modelgen/dscndata1/dronet/models/dronet_clean/train/right/'+x[:-1]
    print(yy)
    # read the input image
    img = Image.open(yy)

    # compute the size(width, height) of image
    size = img.size
    print("Size of the Original image:", size)

    # define transformt o resize the image with given size
    #transform = T.Resize(size = (32,32))

    # apply the transform on the input image
    # img = transform(img)
    resize = T.resize(img, size=[32, 32])
    print("Size after resize:", resize.size)
    #plt.imshow(img)
    resize.save(yy)
    #save_image(resize, yy)
    #break
    #plt.show()
# Out:
# /home/lamda/Desktop/Avd/trojai-master/scripts/modelgen/dscndata1/dronet/models/dronet_clean/train/right/1479424439164932200.png
# Size of the Original image: (640, 480)
# Size after resize: (32, 32)
# /home/lamda/Desktop/Avd/trojai-master/scripts/modelgen/dscndata1/dronet/models/dronet_clean/train/right/1479424439214827638.png
# Size of the Original image: (640, 480)
# Size after resize: (32, 32)
# /home/lamda/Desktop/Avd/trojai-master/scripts/modelgen/dscndata1/dronet/models/dronet_clean/train/right/1479424439264861824.png
# Size of the Original image: (640, 480)
# Size after resize: (32, 32)
# /home/lamda/Desktop/Avd/trojai-master/scripts/modelgen/dscndata1/dronet/models/dronet_clean/train/right/1479424439314867765.png
# Size of the Original image: (640, 480)
# Size after resize: (32, 32)
# /home/lamda/Desktop/Avd/trojai-master/scripts/modelgen/dscndata1/dronet/models/dronet_clean/train/right/1479424439364827723.png
# Size of the Original image: (640, 480)
# ...

# %%
x = [9, 10, 11, 12, 13, 14, 15, 16]
for i in x:
    y = i % 4
    print(y)
# Out:
# 1
# 2
# 3
# 0
# 1
# 2
# 3
# 0

# %%
-0.0234 * (-1)
# Out:
# 0.0234

# %%
[ 0.001, .999]
# Out:
# [0.001, 0.999]

# %%
for i in [.01, 0.3, 0.5, -.01, -0.3, -0.5]:
    if(i > .001 and i < 0.29999):
        label = 1
        print(label)
    elif(i > 0.29999 and i < 0.499999):
        label = 3
        print(label)
    elif(i > 0.49999 and i < 0.699999):
        label = 5
        print(label)
    elif (i > -0.0029999 and i < 0.099):
        label = 100 * 1
        print(label)
# Out:
# 1
# 3
# 5

# %%
if ( .001 == 0.001):
    print(True)
# Out:
# True
