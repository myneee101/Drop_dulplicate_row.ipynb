# %%
fout = open("/home/lamda/Desktop/collision/collision_dataset/training/GOPR0387/train.csv", "w")
fout.write('file,label\n')

f = open("/home/lamda/Desktop/collision/collision_dataset/training/GOPR0387/list.txt", "r")
label = open("/home/lamda/Desktop/collision/collision_dataset/training/GOPR0387/labels.txt", "r")
for x in f:
    xx = label.readline()
    yy = 'train/'+x[:-1]+','+xx
    print(yy)    
    fout.write(yy)
fout.close()
f.close()
label.close()
# Out:
# train/frame_00001.jpg,0
#
# train/frame_00002.jpg,0
#
# train/frame_00003.jpg,0
#
# train/frame_00004.jpg,0
#
# train/frame_00005.jpg,0
#
# train/frame_00006.jpg,0
#
# train/frame_00007.jpg,0
#
# train/frame_00008.jpg,0
#
# train/frame_00009.jpg,0
#
# train/frame_00010.jpg,0
#
# train/frame_00011.jpg,0
#
# train/frame_00012.jpg,0
#
# train/frame_00013.jpg,0
#
# train/frame_00014.jpg,0
#
# train/frame_00015.jpg,0
#
# train/frame_00016.jpg,0
#
# train/frame_00017.jpg,0
#
# train/frame_00018.jpg,0
#
# train/frame_00019.jpg,0
#
# train/frame_00020.jpg,0
#
# train/frame_00021.jpg,0
#
# train/frame_00022.jpg,0
#
# train/frame_00023.jpg,0
#
# train/frame_00024.jpg,0
#
# train/frame_00025.jpg,0
#
# train/frame_00026.jpg,0
#
# train/frame_00027.jpg,0
#
# train/frame_00028.jpg,0
#
# train/frame_00029.jpg,0
#
# train/frame_00030.jpg,0
#
# train/frame_00031.jpg,0
#
# train/frame_00032.jpg,0
#
# train/frame_00033.jpg,0
#
# train/frame_00034.jpg,0
#
# train/frame_00035.jpg,0
#
# ...

# %%
fout = open("/home/lamda/Desktop/collision/collision_dataset/testing/GOPR0386/test.csv", "w")
fout.write('file,label\n')

f = open("/home/lamda/Desktop/collision/collision_dataset/testing/GOPR0386/list.txt", "r")
label = open("/home/lamda/Desktop/collision/collision_dataset/testing/GOPR0386/labels.txt", "r")
for x in f:
    xx = label.readline()
    yy = 'test/'+x[:-1]+','+xx
    print(yy)    
    fout.write(yy)
fout.close()
f.close()
label.close()
# Out:
# test/frame_00001.jpg,0
#
# test/frame_00002.jpg,0
#
# test/frame_00003.jpg,0
#
# test/frame_00004.jpg,0
#
# test/frame_00005.jpg,0
#
# test/frame_00006.jpg,0
#
# test/frame_00007.jpg,0
#
# test/frame_00008.jpg,0
#
# test/frame_00009.jpg,0
#
# test/frame_00010.jpg,0
#
# test/frame_00011.jpg,0
#
# test/frame_00012.jpg,0
#
# test/frame_00013.jpg,0
#
# test/frame_00014.jpg,0
#
# test/frame_00015.jpg,0
#
# test/frame_00016.jpg,0
#
# test/frame_00017.jpg,0
#
# test/frame_00018.jpg,0
#
# test/frame_00019.jpg,0
#
# test/frame_00020.jpg,0
#
# test/frame_00021.jpg,0
#
# test/frame_00022.jpg,0
#
# test/frame_00023.jpg,0
#
# test/frame_00024.jpg,0
#
# test/frame_00025.jpg,0
#
# test/frame_00026.jpg,0
#
# test/frame_00027.jpg,0
#
# test/frame_00028.jpg,0
#
# test/frame_00029.jpg,0
#
# test/frame_00030.jpg,0
#
# test/frame_00031.jpg,0
#
# test/frame_00032.jpg,0
#
# test/frame_00033.jpg,0
#
# test/frame_00034.jpg,0
#
# test/frame_00035.jpg,0
#
# test/frame_00036.jpg,0
#
# test/frame_00037.jpg,0
#
# ...
